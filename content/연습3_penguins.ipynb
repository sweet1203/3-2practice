# %% [markdown]
# # 수행평가 연습 3 — penguins (펭귄)
#
# > ✍️ **여기를 더블클릭**한 뒤, 아랫줄에 학년·반·번호·이름을 입력하세요.
# >
# > 학년: 　　 반: 　　 번호: 　　 이름:
#
# > 📌 실전 시험과 **같은 형식**입니다. 데이터프레임은 반드시 **`exdf`** 로 저장하세요. 인쇄된 **참고파일(PDF)**을 보고 작성합니다.

# %% [markdown]
# ## 📖 데이터셋 소개 — penguins (펭귄)
#
# 남극에 사는 **펭귄 344마리**를 조사한 데이터입니다. 1~8차시 수업에서 함께 쓴 바로 그 데이터예요.
#
# | 열 이름 | 의미 |
# |---|---|
# | `species` | 종 — Adelie / Chinstrap / Gentoo |
# | `island` | 사는 섬 — Biscoe / Dream / Torgersen |
# | `bill_length_mm` | 부리 길이 (mm) |
# | `bill_depth_mm` | 부리 깊이 (mm) |
# | `flipper_length_mm` | 날개 길이 (mm) |
# | `body_mass_g` | 체중 (g) |
# | `sex` | 성별 — Male / Female |

# %% [markdown]
# ## ⚙️ 연습을 위한 준비 — 시작 전 **한 번만 실행**하세요
#
# > 이 셀은 **연습 환경을 준비하는 코드**입니다(문제와 무관합니다).
# > 실행 후 `준비 완료! ✅` 가 나오면 **1번 문제**부터 시작하세요. (처음 실행은 10~20초 걸릴 수 있어요)

# %%
import micropip
await micropip.install(["pyodide-http", "seaborn"])
import pyodide_http
pyodide_http.patch_all()

import warnings
warnings.filterwarnings("ignore")   # 경고 메시지 숨김

print("준비 완료! ✅")

# %% [markdown]
# ## 1. 데이터 준비
#
# ① 파이썬 데이터 분석에 필요한 **라이브러리 3개**를 불러오시오.
#
# ② 아래 코드를 참고하여 `penguins` 데이터를 불러와 **`exdf`** 로 저장하시오.
#
# ```python
# sns.load_dataset("penguins")
# ```
#
# ③ **결측치가 있으면 삭제**하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 2. 데이터 확인
#
# 데이터의 **앞부분 5행**을 출력하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 3. 통계값
#
# 수치형 열의 **요약 통계**를 출력하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 4. 데이터 크기
#
# 데이터의 **(행, 열) 크기**를 출력하시오.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 5. 기본 그래프 🎨
#
# 날개 길이(`flipper_length_mm`)와 체중(`body_mass_g`)의 **산점도**를 그리시오.
#
# **[그래픽 요소 — 반드시 포함]**
# - 제목: `Flipper length vs body mass`
# - x축 라벨: `flipper_length_mm` / y축 라벨: `body_mass_g`
# - 컬러: **`mediumseagreen`**

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 6. 심화 그래프 (groupby) 🎨
#
# 성별(`sex`)별 **평균 체중(`body_mass_g`)**을 **막대그래프**로 그리시오.
#
# **[그래픽 요소 — 반드시 포함]**
# - 제목: `Mean body mass by sex`
# - x축 라벨: `sex` / y축 라벨: `mean body_mass_g`
# - 컬러: **`orchid`**

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 7. 그래프 분석
#
# 위 **기본·심화 그래프**를 보고 알 수 있는 점을 **2문장**으로 쓰시오.

# %% [markdown]
# ✏️ **답:** (여기를 더블클릭해 2문장으로 작성하세요)
